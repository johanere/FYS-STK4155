# %%
import pandas as pd
import sklearn.preprocessing as sklpre
import sklearn.model_selection as sklms
import sklearn.metrics as sklmet
import matplotlib.pyplot as plt
import numpy as np
import keras
# Out:
# Using TensorFlow backend.

# %%
df = pd.read_csv("gridsearch_1.csv", sep=",")

# %%
df["param_act"]
# Out:
# 0      relu
# 1      relu
# 2      relu
# 3      relu
# 4      relu
#        ...
# 123    relu
# 124    relu
# 125    relu
# 126    relu
# 127    relu
# Name: param_act, Length: 128, dtype: object

# %%
hyper_measure=df[["param_act","param_decay","param_dropout","param_epochs","param_l1","param_l2","param_lr","param_nl1","param_nl2","param_nl3","param_nn1","param_nn2","mean_test_score"]]

# %%
hyper_measure
# Out:
#     param_act  param_decay  param_dropout  param_epochs  param_l1  param_l2  \
# 0        relu     0.000001            0.0             3     0.000     0.000
# 1        relu     0.000001            0.0             3     0.000     0.000
# 2        relu     0.000001            0.0             3     0.000     0.000
# 3        relu     0.000001            0.0             3     0.000     0.000
# 4        relu     0.000001            0.0             3     0.000     0.000
# ..        ...          ...            ...           ...       ...       ...
# 123      relu     0.000000            0.1             3     0.001     0.001
# 124      relu     0.000000            0.1             3     0.001     0.001
# 125      relu     0.000000            0.1             3     0.001     0.001
# 126      relu     0.000000            0.1             3     0.001     0.001
# 127      relu     0.000000            0.1             3     0.001     0.001
#
# ...

# %%
hp=hyper_measure.drop(["param_act"],axis=1)

# %%
hp
# Out:
#      param_decay  param_dropout  param_epochs  param_l1  param_l2  param_lr  \
# 0       0.000001            0.0             3     0.000     0.000   0.01000
# 1       0.000001            0.0             3     0.000     0.000   0.01000
# 2       0.000001            0.0             3     0.000     0.000   0.01000
# 3       0.000001            0.0             3     0.000     0.000   0.01000
# 4       0.000001            0.0             3     0.000     0.000   0.00001
# ..           ...            ...           ...       ...       ...       ...
# 123     0.000000            0.1             3     0.001     0.001   0.01000
# 124     0.000000            0.1             3     0.001     0.001   0.00001
# 125     0.000000            0.1             3     0.001     0.001   0.00001
# 126     0.000000            0.1             3     0.001     0.001   0.00001
# 127     0.000000            0.1             3     0.001     0.001   0.00001
#
# ...

# %%
import seaborn as sns
fig, ax = plt.subplots(figsize=(10 * 1.618, 10))
sns.heatmap(hp.corr(), cmap="YlGnBu", ax=ax, square=True, annot=True, cbar=False)
fig.tight_layout()
plt.title("Corrolation matrix")
plt.show()

# %%
hp.sort_values(by=['param_lr'])
# Out:
#     param_decay  param_dropout  param_epochs  param_l1  param_l2  param_lr  \
# 63     0.000001            0.1             3     0.001     0.001   0.00001
# 79     0.000000            0.0             3     0.000     0.001   0.00001
# 78     0.000000            0.0             3     0.000     0.001   0.00001
# 77     0.000000            0.0             3     0.000     0.001   0.00001
# 76     0.000000            0.0             3     0.000     0.001   0.00001
# ..          ...            ...           ...       ...       ...       ...
# 73     0.000000            0.0             3     0.000     0.001   0.01000
# 72     0.000000            0.0             3     0.000     0.001   0.01000
# 27     0.000001            0.0             3     0.001     0.001   0.01000
# 90     0.000000            0.0             3     0.001     0.001   0.01000
# 0      0.000001            0.0             3     0.000     0.000   0.01000
#
# ...

# %%
hp.sort_values(by=['param_nl2'])
# Out:
#      param_decay  param_dropout  param_epochs  param_l1  param_l2  param_lr  \
# 0       0.000001            0.0             3     0.000     0.000   0.01000
# 57      0.000001            0.1             3     0.001     0.001   0.01000
# 56      0.000001            0.1             3     0.001     0.001   0.01000
# 53      0.000001            0.1             3     0.001     0.000   0.00001
# 52      0.000001            0.1             3     0.001     0.000   0.00001
# ..           ...            ...           ...       ...       ...       ...
# 50      0.000001            0.1             3     0.001     0.000   0.01000
# 47      0.000001            0.1             3     0.000     0.001   0.00001
# 46      0.000001            0.1             3     0.000     0.001   0.00001
# 62      0.000001            0.1             3     0.001     0.001   0.00001
# 127     0.000000            0.1             3     0.001     0.001   0.00001
#
# ...

# %%
is_lr_small =  hp['param_lr']<0.001
hp[is_lr_small].mean()
# Out:
# param_decay        5.000000e-07
# param_dropout      5.000000e-02
# param_epochs       3.000000e+00
# param_l1           5.000000e-04
# param_l2           5.000000e-04
# param_lr           1.000000e-05
# param_nl1          0.000000e+00
# param_nl2          5.000000e-01
# param_nl3          0.000000e+00
# param_nn1          1.200000e+01
# param_nn2          9.500000e+00
# mean_test_score   -1.639158e+00
# dtype: float64

# %%
is_lr_large=  hp['param_lr']>=0.001
hp[is_lr_large].mean()
# Out:
# param_decay        5.000000e-07
# param_dropout      5.000000e-02
# param_epochs       3.000000e+00
# param_l1           5.000000e-04
# param_l2           5.000000e-04
# param_lr           1.000000e-02
# param_nl1          0.000000e+00
# param_nl2          5.000000e-01
# param_nl3          0.000000e+00
# param_nn1          1.200000e+01
# param_nn2          9.500000e+00
# mean_test_score   -5.661527e-01
# dtype: float64

# %%
is_nl2_large=  hp['param_nl2']>0
hp[is_nl2_large].mean()
# Out:
# param_decay        5.000000e-07
# param_dropout      5.000000e-02
# param_epochs       3.000000e+00
# param_l1           5.000000e-04
# param_l2           5.000000e-04
# param_lr           5.005000e-03
# param_nl1          0.000000e+00
# param_nl2          1.000000e+00
# param_nl3          0.000000e+00
# param_nn1          1.200000e+01
# param_nn2          9.500000e+00
# mean_test_score   -1.047442e+00
# dtype: float64

# %%
is_nl2_large=  hp['param_nl2']<1e-6
hp[is_nl2_large].mean()
# Out:
# param_decay        5.000000e-07
# param_dropout      5.000000e-02
# param_epochs       3.000000e+00
# param_l1           5.000000e-04
# param_l2           5.000000e-04
# param_lr           5.005000e-03
# param_nl1          0.000000e+00
# param_nl2          0.000000e+00
# param_nl3          0.000000e+00
# param_nn1          1.200000e+01
# param_nn2          9.500000e+00
# mean_test_score   -1.102655e+00
# dtype: float64

# %% [markdown]
# LR by far the most important - 1e-2 better than 1e-5
# NL2 second most important - nl2=1 better than 0
